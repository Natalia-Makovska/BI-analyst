# %% [markdown]
# # HW_8

# %%
import pandas as pd

# %% [markdown]
# 2.Load the movies dataset into pandas.

# %%
movies = pd.read_csv('movies.csv')
movies
# Out:
#                                   Film    Genre            Lead Studio  \
# 0           Zack and Miri Make a Porno  Romance  The Weinstein Company
# 1                      Youth in Revolt   Comedy  The Weinstein Company
# 2   You Will Meet a Tall Dark Stranger   Comedy            Independent
# 3                         When in Rome   Comedy                 Disney
# 4                What Happens in Vegas   Comedy                    Fox
# ..                                 ...      ...                    ...
# 72                 Across the Universe  romance            Independent
# 73                       A Serious Man    Drama              Universal
# 74                  A Dangerous Method    Drama            Independent
# 75                          27 Dresses   Comedy                    Fox
# 76                (500) Days of Summer   comedy                    Fox
#
#     Audience score %  Profitability  Rotten Tomatoes % Worldwide Gross  Year
# ...

# %% [markdown]
# 3.List all dataset columns and examine their types. Explore the various fields’ statistics.Describe what data we have.

# %%
movies.dtypes
# Out:
# Film                  object
# Genre                 object
# Lead Studio           object
# Audience score %       int64
# Profitability        float64
# Rotten Tomatoes %      int64
# Worldwide Gross       object
# Year                   int64
# dtype: object

# %%
movies.describe(include='all')
# Out:
#               Film   Genre  Lead Studio  Audience score %  Profitability  \
# count           77      77           77         77.000000      77.000000
# unique          75      10           13               NaN            NaN
# top     Mamma Mia!  Comedy  Independent               NaN            NaN
# freq             2      41           19               NaN            NaN
# mean           NaN     NaN          NaN         63.727273       4.599483
# std            NaN     NaN          NaN         13.657113       8.031990
# min            NaN     NaN          NaN         35.000000       0.000000
# 25%            NaN     NaN          NaN         52.000000       1.751351
# 50%            NaN     NaN          NaN         64.000000       2.642353
# 75%            NaN     NaN          NaN         76.000000       5.103117
# max            NaN     NaN          NaN         89.000000      66.934000
#
#         Rotten Tomatoes % Worldwide Gross         Year
# ...

# %% [markdown]
# 4.How many movies are there in the dataset in total?

# %%
movies['Film'].value_counts().sum()
# Out:
# 77

# %% [markdown]
# 5.How many movies are there in the dataset for each year?

# %%
movies_per_year = movies.groupby('Year').agg(total_Film=('Film', 'count')) 
movies_per_year
# Out:
#       total_Film
# Year
# 2007          11
# 2008          20
# 2009          12
# 2010          20
# 2011          14

# %% [markdown]
# 6.Show the details of the least and most profitable movies in the dataset.

# %%
most_profitable = movies.max()
most_profitable
# Out:
# Film                 Zack and Miri Make a Porno
# Genre                                   romance
# Lead Studio                        Warner Bros.
# Audience score %                             89
# Profitability                            66.934
# Rotten Tomatoes %                            96
# Worldwide Gross                         $96.16
# Year                                       2011
# dtype: object

# %%
least_profitable = movies.min()
least_profitable
# Out:
# Film                 (500) Days of Summer
# Genre                              Action
# Lead Studio              20th Century Fox
# Audience score %                       35
# Profitability                         0.0
# Rotten Tomatoes %                       3
# Worldwide Gross                    $0.03
# Year                                 2007
# dtype: object

# %% [markdown]
# 7.The ‘Genre’ value seems to be inconsistent at times; try to find these inconsistenciesand fix them.

# %%
movies['Genre'] = movies['Genre'].str.capitalize()
movies
# Out:
#                                   Film    Genre            Lead Studio  \
# 0           Zack and Miri Make a Porno  Romance  The Weinstein Company
# 1                      Youth in Revolt   Comedy  The Weinstein Company
# 2   You Will Meet a Tall Dark Stranger   Comedy            Independent
# 3                         When in Rome   Comedy                 Disney
# 4                What Happens in Vegas   Comedy                    Fox
# ..                                 ...      ...                    ...
# 72                 Across the Universe  Romance            Independent
# 73                       A Serious Man    Drama              Universal
# 74                  A Dangerous Method    Drama            Independent
# 75                          27 Dresses   Comedy                    Fox
# 76                (500) Days of Summer   Comedy                    Fox
#
#     Audience score %  Profitability  Rotten Tomatoes % Worldwide Gross  Year
# ...

# %% [markdown]
# 8.Save (to a new CSV file) the top 10 comedies by audience score; show only moviename, year, and lead studio.

# %%
top_movies = movies.sort_values('Audience score %', ascending=False)
top_movies = top_movies.head(10)
top_movies
# Out:
#                     Film      Genre            Lead Studio  Audience score %  \
# 74    A Dangerous Method      Drama            Independent                89
# 6                 WALL-E  Animation                 Disney                89
# 22               Tangled  Animation                 Disney                88
# 39  My Week with Marilyn      Drama  The Weinstein Company                84
# 72   Across the Universe    romance            Independent                84
# 43     Midnight in Paris    Romence                   Sony                84
# 54            Knocked Up     Comedy              Universal                83
# 12              Twilight    Romance                 Summit                82
# 31       P.S. I Love You    Romance            Independent                82
# 76  (500) Days of Summer     comedy                    Fox                81
#
#     Profitability  Rotten Tomatoes % Worldwide Gross  Year
# 74       0.448645                 79          $8.97   2011
# ...

# %%
top_movies_sort = top_movies[["Film", "Year", "Lead Studio"]]
top_movies_sort
# Out:
#                     Film  Year            Lead Studio
# 74    A Dangerous Method  2011            Independent
# 6                 WALL-E  2008                 Disney
# 22               Tangled  2010                 Disney
# 39  My Week with Marilyn  2011  The Weinstein Company
# 72   Across the Universe  2007            Independent
# 43     Midnight in Paris  2011                   Sony
# 54            Knocked Up  2007              Universal
# 12              Twilight  2008                 Summit
# 31       P.S. I Love You  2007            Independent
# 76  (500) Days of Summer  2009                    Fox

# %%
top_movies_sort.to_csv('top_movies_sort.csv', index=False)

# %%
import lxml as lx
