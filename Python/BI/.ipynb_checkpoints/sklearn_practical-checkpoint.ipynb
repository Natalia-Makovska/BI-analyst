# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split
from sklearn import metrics
import numpy as np
from sklearn.neighbors import KNeighborsClassifier

# %%
dataset_link = 'https://raw.githubusercontent.com/rfordatascience/tidytuesday/master/data/2020/2020-11-03/ikea.csv'
ikea_df = pd.read_csv(dataset_link)
print(ikea_df.shape)
ikea_df.head()
# Out:
# (3694, 14)
#    Unnamed: 0   item_id                   name       category   price  \
# 0           0  90420332               FREKVENS  Bar furniture   265.0
# 1           1    368814              NORDVIKEN  Bar furniture   995.0
# 2           2   9333523  NORDVIKEN / NORDVIKEN  Bar furniture  2095.0
# 3           3  80155205                   STIG  Bar furniture    69.0
# 4           4  30180504                NORBERG  Bar furniture   225.0
#
#       old_price  sellable_online  \
# 0  No old price             True
# 1  No old price            False
# 2  No old price            False
# 3  No old price             True
# 4  No old price             True
#
#                                                 link other_colors  \
# 0  https://www.ikea.com/sa/en/p/frekvens-bar-tabl...           No
# 1  https://www.ikea.com/sa/en/p/nordviken-bar-tab...           No
# 2  https://www.ikea.com/sa/en/p/nordviken-nordvik...           No
# ...

# %%
fig = plt.figure()
ax = fig.add_subplot(projection='3d')

# sns.scatterplot(y=ikea_df.price, x=ikea_df.width, z=ikea_df.height * ikea_df.depth)

ax.set_xlabel('X Label')
ax.set_ylabel('Y Label')
ax.set_zlabel('Z Label')

for x, y, z in zip(ikea_df.width, ikea_df.depth, ikea_df.height):
    ax.scatter(x, y, z)
plt.show()

# %%
X = ikea_df[['category']].values
X
# Out:
# array([['Bar furniture'],
#        ['Bar furniture'],
#        ['Bar furniture'],
#        ...,
#        ['Wardrobes'],
#        ['Wardrobes'],
#        ['Wardrobes']], dtype=object)

# %%
le = LabelEncoder()

for i in range(len(X[0])):
    X[:, i] = le.fit_transform(X[:, i])
    
X
# Out:
# array([[0],
#        [0],
#        [0],
#        ...,
#        [16],
#        [16],
#        [16]], dtype=object)

# %%
y = ikea_df.designer
y.values
# Out:
# array(['Nicholai Wiig Hansen', 'Francis Cayouette', 'Francis Cayouette',
#        ..., 'Ehlén Johansson', 'Ehlén Johansson', 'Ehlén Johansson'],
#       dtype=object)

# %%
ley = LabelEncoder()
y = ley.fit_transform(y)

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y)

# %%
knn = KNeighborsClassifier(n_neighbors=5)

# %%
knn.fit(X_train, y_train)
# Out:
# KNeighborsClassifier()

# %%
peridictions = knn.predict(X_test)

# %%
accuracy = metrics.accuracy_score(y_test, peridictions)

# %%
mean_squared_error?

# %%
df = sns.load_dataset('titanic')
df.head(10)
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0         0       3    male  22.0      1      0   7.2500        S   Third
# 1         1       1  female  38.0      1      0  71.2833        C   First
# 2         1       3  female  26.0      0      0   7.9250        S   Third
# 3         1       1  female  35.0      1      0  53.1000        S   First
# 4         0       3    male  35.0      0      0   8.0500        S   Third
# 5         0       3    male   NaN      0      0   8.4583        Q   Third
# 6         0       1    male  54.0      0      0  51.8625        S   First
# 7         0       3    male   2.0      3      1  21.0750        S   Third
# 8         1       3  female  27.0      0      2  11.1333        S   Third
# 9         1       2  female  14.0      1      0  30.0708        C  Second
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# ...

# %%
X = df[['class', 'sex', 'fare', 'embarked', 'age']]
y = df['survived']

# %%
from sklearn.pipeline import Pipeline
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import OneHotEncoder, StandardScaler
from sklearn.neighbors import KNeighborsClassifier, KNeighborsRegressor
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, mean_squared_error
from sklearn.compose import ColumnTransformer
from sklearn.tree import DecisionTreeRegressor

# %%
numeric_pipeline = Pipeline(steps=[
    ('impute', SimpleImputer(strategy='mean')),
    ('scale', StandardScaler())
])

categorical_pipeline = Pipeline(steps=[
    ('impute', SimpleImputer(strategy='most_frequent')),
    ('onehot', OneHotEncoder()),
])

preprocessing = ColumnTransformer(transformers=[
    ('numeric_pipeline', numeric_pipeline, ['fare', 'age']),
    ('categorical_pipeline', categorical_pipeline, ['class', 'sex', 'embarked']),
])

model = Pipeline(steps=[
    ('preprocessing', preprocessing),
    ('knc', KNeighborsClassifier(n_neighbors=10)),
])

X_train, X_test, y_train, y_test = train_test_split(X, y)
model.fit(X_train, y_train)

predict = model.predict(X_test)
accuracy_score(y_test, predict)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~/opt/anaconda3/lib/python3.8/site-packages/sklearn/utils/__init__.py in _get_column_indices(X, key)
#     373         try:
# --> 374             all_columns = X.columns
#     375         except AttributeError:
#
# AttributeError: 'numpy.ndarray' object has no attribute 'columns'
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# <ipython-input-45-c46397f3087c> in <module>
#      20
#      21 X_train, X_test, y_train, y_test = train_test_split(X, y)
# ---> 22 model.fit(X_train, y_train)
#      23
#      24 predict = model.predict(X_test)
#
# ~/opt/anaconda3/lib/python3.8/site-packages/sklearn/pipeline.py in fit(self, X, y, **fit_params)
#     339         """
# ...

# %%
ikea_df.head()
# Out:
#    Unnamed: 0   item_id                   name       category   price  \
# 0           0  90420332               FREKVENS  Bar furniture   265.0
# 1           1    368814              NORDVIKEN  Bar furniture   995.0
# 2           2   9333523  NORDVIKEN / NORDVIKEN  Bar furniture  2095.0
# 3           3  80155205                   STIG  Bar furniture    69.0
# 4           4  30180504                NORBERG  Bar furniture   225.0
#
#       old_price  sellable_online  \
# 0  No old price             True
# 1  No old price            False
# 2  No old price            False
# 3  No old price             True
# 4  No old price             True
#
#                                                 link other_colors  \
# 0  https://www.ikea.com/sa/en/p/frekvens-bar-tabl...           No
# 1  https://www.ikea.com/sa/en/p/nordviken-bar-tab...           No
# 2  https://www.ikea.com/sa/en/p/nordviken-nordvik...           No
# 3  https://www.ikea.com/sa/en/p/stig-bar-stool-wi...          Yes
# ...

# %%
droped = ikea_df.dropna()
X = droped[['depth',  'width']]
y = droped['price']


numeric_pipeline = Pipeline(steps=[
#     ('impute', SimpleImputer(strategy='most_frequent')),
    ('scale', StandardScaler())
])

categorical_pipeline = Pipeline(steps=[
#     ('impute', SimpleImputer(strategy='most_frequent')),
    ('onehot', OneHotEncoder(handle_unknown = 'ignore')),
])

preprocessing = ColumnTransformer(transformers=[
    ('numeric_pipeline', numeric_pipeline, ['depth', 'width']),
#     ('categorical_pipeline', categorical_pipeline, ['category']),
])

model = Pipeline(steps=[
    ('preprocessing', preprocessing),
    ('regression', DecisionTreeRegressor()),
])

results = []

for _ in range(20):
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=.1)
    model.fit(X_train, y_train)

    model.score(X_test, y_test)
    y_predict = model.predict(X_test)
    print(mean_squared_error(y_train, model.predict(X_train)))
    result = mean_squared_error(y_test, y_predict)
    results.append(result)
    
print('Mean:', np.mean(results))
# Out:
# 127375.49709375725
# 118138.43080521561
# 111772.17526732049
# 129977.60522764824
# 127947.25785919001
# 131554.12905202006
# 115416.74663173263
# 113626.35128194958
# 122087.34369355213
# 127560.32881441407
# 122261.23447860571
# 126425.66928598238
# 125967.8455640406
# 119166.9339481152
# 122310.73768226684
# 125624.83269856828
# 120558.51052393894
# 128239.37723556487
# 126325.62537606593
# 125789.38908610838
# Mean: 359437.00274189754

# %%
corr = ikea_df.corr()
corr.style.background_gradient(cmap='coolwarm')
# Out:
# <style  type="text/css" >
# #T_4ce61_row0_col0,#T_4ce61_row1_col1,#T_4ce61_row2_col2,#T_4ce61_row3_col3,#T_4ce61_row4_col4,#T_4ce61_row5_col5,#T_4ce61_row6_col6{
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }#T_4ce61_row0_col1,#T_4ce61_row1_col0{
#             background-color:  #3f53c6;
#             color:  #f1f1f1;
#         }#T_4ce61_row0_col2{
#             background-color:  #6c8ff1;
#             color:  #000000;
#         }#T_4ce61_row0_col3,#T_4ce61_row1_col3,#T_4ce61_row1_col6,#T_4ce61_row3_col0,#T_4ce61_row3_col1,#T_4ce61_row3_col2,#T_4ce61_row3_col6,#T_4ce61_row4_col5,#T_4ce61_row5_col4{
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }#T_4ce61_row0_col4{
#             background-color:  #8db0fe;
#             color:  #000000;
#         }#T_4ce61_row0_col5{
#             background-color:  #6a8bef;
#             color:  #000000;
#         }#T_4ce61_row0_col6,#T_4ce61_row4_col3{
# ...

# %%
X = [
    [0, 0],
    [1, 1],
    [2, 0],
    [0, 1],
    [20, 20],
    [21, 20],
    [19, 20],
    [21, 20],
    [29, 22],
]

y = [
    1, 1, 1, 1, 2, 2, 2, 2, 2
]

model = KNeighborsClassifier(n_neighbors=2)
model.fit(X, y)


model.predict([[23, 19]])
# Out:
# array([2])
